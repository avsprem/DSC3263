# %% [markdown]
# ### Importing necessary Libraries
# tabula - to read table in to pandas DF <br>
# PyPDF2.pdfreader - to read rainfall data

# %%
import tabula
from PyPDF2 import PdfReader
import pandas as pd
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
import numpy as np

# %% [markdown]
# We need to maintain a date variable to add to dataframe and save the data files

# %%
date = '2023-06-02'
new_date = date.replace("-", "_")

# %% [markdown]
# Link to the PDF

# %%
path = "C:/Users/User/Desktop/Project/pdf_files/jun/"+ new_date +".pdf"

# %% [markdown]
# Reading table data into padas DF

# %%
try:
    tabula.convert_into(path, "output.csv", output_format="csv", pages='1')
    print("converted")

except Exception as e:
    print("Error {}".format(e))
# Out:
# converted

# %% [markdown]
# Clean the Data Set by removing unnecessary columns, null rows and table headers

# %%
df = pd.read_csv("output.csv",skiprows=2,header=None)
df.drop(df.columns[[0] + list(range(11, len(df.columns)))], axis=1, inplace=True)
df = df.dropna(thresh=5)
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# Cleaned Dataframe

# %%
df
# Out:
#                   1                         2   3      4      5      6   \
# 0       Kelani Ganga                 N' Street  ft   4.00   5.00   7.00
# 1       Kelani Ganga                  Hanwella   m   7.00   8.00  10.00
# 2       Kelani Ganga                Glencourse   m  15.00  16.50  19.00
# 3       Kelani Ganga                 Kitulgala   m   3.00   4.00   6.00
# 4       Gurugoda Oya                 Holombuwa   m   3.00   3.40   5.00
# 5   Seethawaka Ganga              Deraniyagala   m   4.80   5.80   6.40
# 6      Kehelgamu Oya                   Norwood   m   1.50   3.00   4.50
# 7         Kalu Ganga                 Putupaula   m   3.00   4.00   5.00
# 8         Kalu Ganga                  Ellagawa   m  10.00  10.70  12.20
# 9         Kalu Ganga                 Ratnapura   m   5.20   7.50   9.50
# 10      Maguru Ganga                    Magura   m   4.00   6.00   7.50
# 11        Kuda Ganga  Kalawellawa (Millakanda)   m   5.00   6.50   8.00
# 12         Gin Ganga                  Tawalama   m   4.00   6.00   7.50
# 13         Gin Ganga                 Baddegama   m   3.50   4.00   5.00
# 14     Nilwala Ganga              Thalgahagoda   m   1.40   1.70   2.80
# 15     Nilwala Ganga                Panadugama   m   5.00   6.00   7.50
# 16     Nilwala Ganga               Pitabeddara   m   4.00   5.00   6.50
# 17    Urubokka Ganga                     Urawa   m   2.50   4.00   6.00
# 18      Walawe Ganga                Moraketiya   m   1.80   3.50   5.00
# 19       Kirindi Oya               Tanamalwila   m   4.00   5.00   5.50
# 20       Kirindi Oya                 Wellawaya   m   4.40   5.40   5.90
# 21          Kuda Oya                  Kuda Oya   m   6.90   8.40   8.80
# 22       Menik Ganga               Katharagama   m   4.00   4.60   6.50
# 23     Kumbukkan Oya                   Nakkala   m   5.00   6.00   7.50
# 24          Heda Oya            Siyambalanduwa   m   4.50   6.00   7.00
# 25        Maduru Oya              Padiyatalawa   m   4.00   4.50   6.00
# 26               NaN        Manampitiya ( Old)   m   3.50   5.00   6.00
# 27    Mahaweli Ganga        Manampitiya (HMIS)   m   4.65   6.15   7.15
# 28    Mahaweli Ganga               Weragantota   m   5.00   6.00   8.00
# 29    Mahaweli Ganga                Peradeniya   m   5.00   7.00   9.00
# 30    Mahaweli Ganga              Nawalapitiya   m   3.50   5.00   6.00
# 31        Badulu Oya                   Taldena   m   3.00   4.00   5.00
# 32           Yan Oya               Horowpatana   m   6.00   7.50  10.50
# 33        Mukunu Oya                  Yakawewa   m   4.00   5.00   6.00
# 34      Malwathu Oya               Tantirimale   m   5.00   6.80   7.80
# 35           Mee Oya                 Galgamuwa   m   4.84   5.94   8.00
# 36        Deduru Oya               Moragaswewa   m      -      -      -
# 37          Maha Oya                 Badalgama   m   5.00   6.20   9.60
# 38          Maha Oya                  Giriulla   m   5.50   6.50   7.50
# 39    Attanagalu Oya                  Dunamale   m   3.30   4.40   5.50
#
#        7      8            9        10
# 0    1.20   1.50       Normal      NaN
# 1    3.07   3.21       Normal      NaN
# 2   12.03  11.77       Normal      NaN
# 3    1.65   1.54       Normal      NaN
# 4    0.23   0.23       Normal      NaN
# 5    1.46   1.37       Normal      NaN
# 6    0.60   0.59       Normal      NaN
# 7    1.60   1.69       Normal      NaN
# 8    8.01   8.12       Normal      NaN
# 9    5.25   5.16       Normal      NaN
# 10   5.91   5.97        Alert   Rising
# 11   5.15   5.27        Alert   Rising
# 12   5.47   5.58        Alert   Rising
# 13   3.53   3.55        Alert   Rising
# 14   1.38   1.40        Alert   Rising
# 15   6.18   6.05  Minor Flood  Falling
# 16   2.00   2.05       Normal      NaN
# 17   1.70   1.66       Normal      NaN
# 18   0.85   0.86       Normal      NaN
# 19   0.38   0.37       Normal      NaN
# 20   0.72   0.72       Normal      NaN
# 21   1.23   1.22       Normal      NaN
# 22  -0.19  -0.19       Normal      NaN
# 23   0.84   0.83       Normal      NaN
# 24   0.48   0.48       Normal      NaN
# 25   0.29   0.29       Normal      NaN
# 26  -0.72  -0.72       Normal      NaN
# 27   0.42   0.42       Normal      NaN
# 28  -2.64  -2.67       Normal      NaN
# 29   1.12   1.18       Normal      NaN
# 30   0.84   0.88       Normal      NaN
# 31   0.47   0.47       Normal      NaN
# 32   1.55   1.55       Normal      NaN
# 33   0.49   0.49       Normal      NaN
# 34   1.13   1.13       Normal      NaN
# 35   0.02   0.02       Normal      NaN
# 36   0.32   0.32       Normal      NaN
# 37   1.87   1.87       Normal      NaN
# 38   0.82   0.82       Normal      NaN
# 39   0.70   0.70       Normal      NaN

# %% [markdown]
# Reading the rainfall Data into Pandas Series

# %%
reader = PdfReader(path)
number_of_pages = len(reader.pages)
page = reader.pages[0]
text = page.extract_text()

# text processing logic
extracted_values = []
for i in range(len(text.split("\n")[:-3])):
    if len(text.split("\n")[i]) > 40:
        extracted_values.append(text.split("\n")[i].split(" ")[-1])

# Create a Pandas Series
rf_data = pd.Series(extracted_values)

# %%
rf_data
# Out:
# 0          -
# 1       16.2
# 2       26.5
# 3       25.6
# 4        2.5
# 5      175.8
# 6        5.5
# 7       15.0
# 8      100.7
# 9      141.3
# 10      49.0
# 11      15.5
# 12      77.9
# 13      45.7
# 14      38.4
# 15       7.5
# 16     132.3
# 17      42.7
# 18       9.5
# 19       0.0
# 20       0.0
# 21       0.0
# 22       0.0
# 23       0.0
# 24       0.0
# 25       0.0
# 26       0.0
# 27       0.0
# 28       0.0
# 29       0.0
# 30       0.0
# 31       0.0
# 32       0.0
# 33       0.0
# 34       0.0
# 35       0.0
# 36       0.0
# 37       1.3
# 38       0.3
# 39       0.1
# 40
# 41    Rivers
# dtype: object

# %% [markdown]
# Convering Rainfall data from String into numeric type, cleaning and add to the datafame as a new column

# %%
rf_data= rf_data[0:40]
rf_data = pd.to_numeric(rf_data, errors='coerce').fillna(0)
df = pd.concat([df, rf_data], axis=1)

# %% [markdown]
# Rename the Dataframe Columns

# %%
df.columns = ["Tributory/River", "Station", "Unit", "Alert Level", "Minor Flood Level", "Major Flood Level", "Water Level at 8:00 am", "Water Level at 9:00 am", "Remarks", "Water Level Rising or Falling", "24 Hr RF in mm at 8.30 am"]

# %% [markdown]
# Fill NaN values of "Tributory/River" and "Water Level Rising or Falling" columns

# %%
df["Tributory/River"]=df["Tributory/River"].fillna("Mahaweli Ganga")
df["Water Level Rising or Falling"]=df["Water Level Rising or Falling"].fillna("Stable")

# %% [markdown]
# Add the "River Basin" column according to the "Tributory/River"

# %%
# Dictionary
river_dict = {
    "Kelani Ganga": "Kelani Ganga(RB 01)",
    "Gurugoda Oya": "Kelani Ganga(RB 01)",
    "Seethawaka Ganga": "Kelani Ganga(RB 01)",
    "Kehelgamu Oya": "Kelani Ganga(RB 01)",
    "Kalu Ganga": "Kalu Ganga(RB 03)",
    "Maguru Ganga": "Kalu Ganga(RB 03)",
    "Kuda Ganga": "Kalu Ganga(RB 03)",
    "Gin Ganga": "Gin Ganga(RB 09)",
    "Nilwala Ganga": "Nilwala Ganga(RB 12)",
    "Urubokka Ganga": "Nilwala Ganga(RB 12)",
    "Walawe Ganga": "Walawe Ganga(RB 18)",
    "Kirindi Oya": "Kirindi Oya(RB 22)",
    "Kuda Oya": "Kirindi Oya(RB 22)",
    "Menik Ganga": "Menik Ganga(RB 26)",
    "Kumbukkan Oya": "Kumbukkan Oya(RB 31)",
    "Heda Oya": "Heda Oya(RB 36)",
    "Maduru Oya": "Maduru Oya(RB 54)",
    "Mahaweli Ganga": "Mahaweli Ganga(RB 60)",
    "Badulu Oya": "Mahaweli Ganga(RB 60)",
    "Yan Oya": "Yan Oya(RB 67)",
    "Mukunu Oya": "Maa Oya(RB 69)",
    "Malwathu Oya": "Malwathu Oya(RB 90)",
    "Mee Oya": "Mee Oya(RB 95)",
    "Deduru Oya": "Deduru Oya(RB 99)",
    "Maha Oya": "Maha Oya(RB 102)",
    "Attanagalu Oya": "Attanagalu Oya(RB 103)"
}

# %%
df.insert(0, "River Basin", df["Tributory/River"].map(river_dict))

# %%
df
# Out:
#                River Basin   Tributory/River                   Station Unit  \
# 0      Kelani Ganga(RB 01)      Kelani Ganga                 N' Street   ft
# 1      Kelani Ganga(RB 01)      Kelani Ganga                  Hanwella    m
# 2      Kelani Ganga(RB 01)      Kelani Ganga                Glencourse    m
# 3      Kelani Ganga(RB 01)      Kelani Ganga                 Kitulgala    m
# 4      Kelani Ganga(RB 01)      Gurugoda Oya                 Holombuwa    m
# 5      Kelani Ganga(RB 01)  Seethawaka Ganga              Deraniyagala    m
# 6      Kelani Ganga(RB 01)     Kehelgamu Oya                   Norwood    m
# 7        Kalu Ganga(RB 03)        Kalu Ganga                 Putupaula    m
# 8        Kalu Ganga(RB 03)        Kalu Ganga                  Ellagawa    m
# 9        Kalu Ganga(RB 03)        Kalu Ganga                 Ratnapura    m
# 10       Kalu Ganga(RB 03)      Maguru Ganga                    Magura    m
# 11       Kalu Ganga(RB 03)        Kuda Ganga  Kalawellawa (Millakanda)    m
# 12        Gin Ganga(RB 09)         Gin Ganga                  Tawalama    m
# 13        Gin Ganga(RB 09)         Gin Ganga                 Baddegama    m
# 14    Nilwala Ganga(RB 12)     Nilwala Ganga              Thalgahagoda    m
# 15    Nilwala Ganga(RB 12)     Nilwala Ganga                Panadugama    m
# 16    Nilwala Ganga(RB 12)     Nilwala Ganga               Pitabeddara    m
# 17    Nilwala Ganga(RB 12)    Urubokka Ganga                     Urawa    m
# 18     Walawe Ganga(RB 18)      Walawe Ganga                Moraketiya    m
# 19      Kirindi Oya(RB 22)       Kirindi Oya               Tanamalwila    m
# 20      Kirindi Oya(RB 22)       Kirindi Oya                 Wellawaya    m
# 21      Kirindi Oya(RB 22)          Kuda Oya                  Kuda Oya    m
# 22      Menik Ganga(RB 26)       Menik Ganga               Katharagama    m
# 23    Kumbukkan Oya(RB 31)     Kumbukkan Oya                   Nakkala    m
# 24         Heda Oya(RB 36)          Heda Oya            Siyambalanduwa    m
# 25       Maduru Oya(RB 54)        Maduru Oya              Padiyatalawa    m
# 26   Mahaweli Ganga(RB 60)    Mahaweli Ganga        Manampitiya ( Old)    m
# 27   Mahaweli Ganga(RB 60)    Mahaweli Ganga        Manampitiya (HMIS)    m
# 28   Mahaweli Ganga(RB 60)    Mahaweli Ganga               Weragantota    m
# 29   Mahaweli Ganga(RB 60)    Mahaweli Ganga                Peradeniya    m
# 30   Mahaweli Ganga(RB 60)    Mahaweli Ganga              Nawalapitiya    m
# 31   Mahaweli Ganga(RB 60)        Badulu Oya                   Taldena    m
# 32          Yan Oya(RB 67)           Yan Oya               Horowpatana    m
# 33          Maa Oya(RB 69)        Mukunu Oya                  Yakawewa    m
# 34     Malwathu Oya(RB 90)      Malwathu Oya               Tantirimale    m
# 35          Mee Oya(RB 95)           Mee Oya                 Galgamuwa    m
# 36       Deduru Oya(RB 99)        Deduru Oya               Moragaswewa    m
# 37        Maha Oya(RB 102)          Maha Oya                 Badalgama    m
# 38        Maha Oya(RB 102)          Maha Oya                  Giriulla    m
# 39  Attanagalu Oya(RB 103)    Attanagalu Oya                  Dunamale    m
#
#    Alert Level Minor Flood Level Major Flood Level  Water Level at 8:00 am  \
# 0         4.00              5.00              7.00                    1.20
# 1         7.00              8.00             10.00                    3.07
# 2        15.00             16.50             19.00                   12.03
# 3         3.00              4.00              6.00                    1.65
# 4         3.00              3.40              5.00                    0.23
# 5         4.80              5.80              6.40                    1.46
# 6         1.50              3.00              4.50                    0.60
# 7         3.00              4.00              5.00                    1.60
# 8        10.00             10.70             12.20                    8.01
# 9         5.20              7.50              9.50                    5.25
# 10        4.00              6.00              7.50                    5.91
# 11        5.00              6.50              8.00                    5.15
# 12        4.00              6.00              7.50                    5.47
# 13        3.50              4.00              5.00                    3.53
# 14        1.40              1.70              2.80                    1.38
# 15        5.00              6.00              7.50                    6.18
# 16        4.00              5.00              6.50                    2.00
# 17        2.50              4.00              6.00                    1.70
# 18        1.80              3.50              5.00                    0.85
# 19        4.00              5.00              5.50                    0.38
# 20        4.40              5.40              5.90                    0.72
# 21        6.90              8.40              8.80                    1.23
# 22        4.00              4.60              6.50                   -0.19
# 23        5.00              6.00              7.50                    0.84
# 24        4.50              6.00              7.00                    0.48
# 25        4.00              4.50              6.00                    0.29
# 26        3.50              5.00              6.00                   -0.72
# 27        4.65              6.15              7.15                    0.42
# 28        5.00              6.00              8.00                   -2.64
# 29        5.00              7.00              9.00                    1.12
# 30        3.50              5.00              6.00                    0.84
# 31        3.00              4.00              5.00                    0.47
# 32        6.00              7.50             10.50                    1.55
# 33        4.00              5.00              6.00                    0.49
# 34        5.00              6.80              7.80                    1.13
# 35        4.84              5.94              8.00                    0.02
# 36           -                 -                 -                    0.32
# 37        5.00              6.20              9.60                    1.87
# 38        5.50              6.50              7.50                    0.82
# 39        3.30              4.40              5.50                    0.70
#
#     Water Level at 9:00 am      Remarks Water Level Rising or Falling  \
# 0                     1.50       Normal                        Stable
# 1                     3.21       Normal                        Stable
# 2                    11.77       Normal                        Stable
# 3                     1.54       Normal                        Stable
# 4                     0.23       Normal                        Stable
# 5                     1.37       Normal                        Stable
# 6                     0.59       Normal                        Stable
# 7                     1.69       Normal                        Stable
# 8                     8.12       Normal                        Stable
# 9                     5.16       Normal                        Stable
# 10                    5.97        Alert                        Rising
# 11                    5.27        Alert                        Rising
# 12                    5.58        Alert                        Rising
# 13                    3.55        Alert                        Rising
# 14                    1.40        Alert                        Rising
# 15                    6.05  Minor Flood                       Falling
# 16                    2.05       Normal                        Stable
# 17                    1.66       Normal                        Stable
# 18                    0.86       Normal                        Stable
# 19                    0.37       Normal                        Stable
# 20                    0.72       Normal                        Stable
# 21                    1.22       Normal                        Stable
# 22                   -0.19       Normal                        Stable
# 23                    0.83       Normal                        Stable
# 24                    0.48       Normal                        Stable
# 25                    0.29       Normal                        Stable
# 26                   -0.72       Normal                        Stable
# 27                    0.42       Normal                        Stable
# 28                   -2.67       Normal                        Stable
# 29                    1.18       Normal                        Stable
# 30                    0.88       Normal                        Stable
# 31                    0.47       Normal                        Stable
# 32                    1.55       Normal                        Stable
# 33                    0.49       Normal                        Stable
# 34                    1.13       Normal                        Stable
# 35                    0.02       Normal                        Stable
# 36                    0.32       Normal                        Stable
# 37                    1.87       Normal                        Stable
# 38                    0.82       Normal                        Stable
# 39                    0.70       Normal                        Stable
#
#     24 Hr RF in mm at 8.30 am
# 0                         0.0
# 1                        16.2
# 2                        26.5
# 3                        25.6
# 4                         2.5
# 5                       175.8
# 6                         5.5
# 7                        15.0
# 8                       100.7
# 9                       141.3
# 10                       49.0
# 11                       15.5
# 12                       77.9
# 13                       45.7
# 14                       38.4
# 15                        7.5
# 16                      132.3
# 17                       42.7
# 18                        9.5
# 19                        0.0
# 20                        0.0
# 21                        0.0
# 22                        0.0
# 23                        0.0
# 24                        0.0
# 25                        0.0
# 26                        0.0
# 27                        0.0
# 28                        0.0
# 29                        0.0
# 30                        0.0
# 31                        0.0
# 32                        0.0
# 33                        0.0
# 34                        0.0
# 35                        0.0
# 36                        0.0
# 37                        1.3
# 38                        0.3
# 39                        0.1

# %% [markdown]
# Limit the rows upto 39 rows to avoid unnecessary rows

# %%
df = df.iloc[0:40]
df
# Out:
#                River Basin   Tributory/River                   Station Unit  \
# 0      Kelani Ganga(RB 01)      Kelani Ganga                 N' Street   ft
# 1      Kelani Ganga(RB 01)      Kelani Ganga                  Hanwella    m
# 2      Kelani Ganga(RB 01)      Kelani Ganga                Glencourse    m
# 3      Kelani Ganga(RB 01)      Kelani Ganga                 Kitulgala    m
# 4      Kelani Ganga(RB 01)      Gurugoda Oya                 Holombuwa    m
# 5      Kelani Ganga(RB 01)  Seethawaka Ganga              Deraniyagala    m
# 6      Kelani Ganga(RB 01)     Kehelgamu Oya                   Norwood    m
# 7        Kalu Ganga(RB 03)        Kalu Ganga                 Putupaula    m
# 8        Kalu Ganga(RB 03)        Kalu Ganga                  Ellagawa    m
# 9        Kalu Ganga(RB 03)        Kalu Ganga                 Ratnapura    m
# 10       Kalu Ganga(RB 03)      Maguru Ganga                    Magura    m
# 11       Kalu Ganga(RB 03)        Kuda Ganga  Kalawellawa (Millakanda)    m
# 12        Gin Ganga(RB 09)         Gin Ganga                  Tawalama    m
# 13        Gin Ganga(RB 09)         Gin Ganga                 Baddegama    m
# 14    Nilwala Ganga(RB 12)     Nilwala Ganga              Thalgahagoda    m
# 15    Nilwala Ganga(RB 12)     Nilwala Ganga                Panadugama    m
# 16    Nilwala Ganga(RB 12)     Nilwala Ganga               Pitabeddara    m
# 17    Nilwala Ganga(RB 12)    Urubokka Ganga                     Urawa    m
# 18     Walawe Ganga(RB 18)      Walawe Ganga                Moraketiya    m
# 19      Kirindi Oya(RB 22)       Kirindi Oya               Tanamalwila    m
# 20      Kirindi Oya(RB 22)       Kirindi Oya                 Wellawaya    m
# 21      Kirindi Oya(RB 22)          Kuda Oya                  Kuda Oya    m
# 22      Menik Ganga(RB 26)       Menik Ganga               Katharagama    m
# 23    Kumbukkan Oya(RB 31)     Kumbukkan Oya                   Nakkala    m
# 24         Heda Oya(RB 36)          Heda Oya            Siyambalanduwa    m
# 25       Maduru Oya(RB 54)        Maduru Oya              Padiyatalawa    m
# 26   Mahaweli Ganga(RB 60)    Mahaweli Ganga        Manampitiya ( Old)    m
# 27   Mahaweli Ganga(RB 60)    Mahaweli Ganga        Manampitiya (HMIS)    m
# 28   Mahaweli Ganga(RB 60)    Mahaweli Ganga               Weragantota    m
# 29   Mahaweli Ganga(RB 60)    Mahaweli Ganga                Peradeniya    m
# 30   Mahaweli Ganga(RB 60)    Mahaweli Ganga              Nawalapitiya    m
# 31   Mahaweli Ganga(RB 60)        Badulu Oya                   Taldena    m
# 32          Yan Oya(RB 67)           Yan Oya               Horowpatana    m
# 33          Maa Oya(RB 69)        Mukunu Oya                  Yakawewa    m
# 34     Malwathu Oya(RB 90)      Malwathu Oya               Tantirimale    m
# 35          Mee Oya(RB 95)           Mee Oya                 Galgamuwa    m
# 36       Deduru Oya(RB 99)        Deduru Oya               Moragaswewa    m
# 37        Maha Oya(RB 102)          Maha Oya                 Badalgama    m
# 38        Maha Oya(RB 102)          Maha Oya                  Giriulla    m
# 39  Attanagalu Oya(RB 103)    Attanagalu Oya                  Dunamale    m
#
#    Alert Level Minor Flood Level Major Flood Level  Water Level at 8:00 am  \
# 0         4.00              5.00              7.00                    1.20
# 1         7.00              8.00             10.00                    3.07
# 2        15.00             16.50             19.00                   12.03
# 3         3.00              4.00              6.00                    1.65
# 4         3.00              3.40              5.00                    0.23
# 5         4.80              5.80              6.40                    1.46
# 6         1.50              3.00              4.50                    0.60
# 7         3.00              4.00              5.00                    1.60
# 8        10.00             10.70             12.20                    8.01
# 9         5.20              7.50              9.50                    5.25
# 10        4.00              6.00              7.50                    5.91
# 11        5.00              6.50              8.00                    5.15
# 12        4.00              6.00              7.50                    5.47
# 13        3.50              4.00              5.00                    3.53
# 14        1.40              1.70              2.80                    1.38
# 15        5.00              6.00              7.50                    6.18
# 16        4.00              5.00              6.50                    2.00
# 17        2.50              4.00              6.00                    1.70
# 18        1.80              3.50              5.00                    0.85
# 19        4.00              5.00              5.50                    0.38
# 20        4.40              5.40              5.90                    0.72
# 21        6.90              8.40              8.80                    1.23
# 22        4.00              4.60              6.50                   -0.19
# 23        5.00              6.00              7.50                    0.84
# 24        4.50              6.00              7.00                    0.48
# 25        4.00              4.50              6.00                    0.29
# 26        3.50              5.00              6.00                   -0.72
# 27        4.65              6.15              7.15                    0.42
# 28        5.00              6.00              8.00                   -2.64
# 29        5.00              7.00              9.00                    1.12
# 30        3.50              5.00              6.00                    0.84
# 31        3.00              4.00              5.00                    0.47
# 32        6.00              7.50             10.50                    1.55
# 33        4.00              5.00              6.00                    0.49
# 34        5.00              6.80              7.80                    1.13
# 35        4.84              5.94              8.00                    0.02
# 36           -                 -                 -                    0.32
# 37        5.00              6.20              9.60                    1.87
# 38        5.50              6.50              7.50                    0.82
# 39        3.30              4.40              5.50                    0.70
#
#     Water Level at 9:00 am      Remarks Water Level Rising or Falling  \
# 0                     1.50       Normal                        Stable
# 1                     3.21       Normal                        Stable
# 2                    11.77       Normal                        Stable
# 3                     1.54       Normal                        Stable
# 4                     0.23       Normal                        Stable
# 5                     1.37       Normal                        Stable
# 6                     0.59       Normal                        Stable
# 7                     1.69       Normal                        Stable
# 8                     8.12       Normal                        Stable
# 9                     5.16       Normal                        Stable
# 10                    5.97        Alert                        Rising
# 11                    5.27        Alert                        Rising
# 12                    5.58        Alert                        Rising
# 13                    3.55        Alert                        Rising
# 14                    1.40        Alert                        Rising
# 15                    6.05  Minor Flood                       Falling
# 16                    2.05       Normal                        Stable
# 17                    1.66       Normal                        Stable
# 18                    0.86       Normal                        Stable
# 19                    0.37       Normal                        Stable
# 20                    0.72       Normal                        Stable
# 21                    1.22       Normal                        Stable
# 22                   -0.19       Normal                        Stable
# 23                    0.83       Normal                        Stable
# 24                    0.48       Normal                        Stable
# 25                    0.29       Normal                        Stable
# 26                   -0.72       Normal                        Stable
# 27                    0.42       Normal                        Stable
# 28                   -2.67       Normal                        Stable
# 29                    1.18       Normal                        Stable
# 30                    0.88       Normal                        Stable
# 31                    0.47       Normal                        Stable
# 32                    1.55       Normal                        Stable
# 33                    0.49       Normal                        Stable
# 34                    1.13       Normal                        Stable
# 35                    0.02       Normal                        Stable
# 36                    0.32       Normal                        Stable
# 37                    1.87       Normal                        Stable
# 38                    0.82       Normal                        Stable
# 39                    0.70       Normal                        Stable
#
#     24 Hr RF in mm at 8.30 am
# 0                         0.0
# 1                        16.2
# 2                        26.5
# 3                        25.6
# 4                         2.5
# 5                       175.8
# 6                         5.5
# 7                        15.0
# 8                       100.7
# 9                       141.3
# 10                       49.0
# 11                       15.5
# 12                       77.9
# 13                       45.7
# 14                       38.4
# 15                        7.5
# 16                      132.3
# 17                       42.7
# 18                        9.5
# 19                        0.0
# 20                        0.0
# 21                        0.0
# 22                        0.0
# 23                        0.0
# 24                        0.0
# 25                        0.0
# 26                        0.0
# 27                        0.0
# 28                        0.0
# 29                        0.0
# 30                        0.0
# 31                        0.0
# 32                        0.0
# 33                        0.0
# 34                        0.0
# 35                        0.0
# 36                        0.0
# 37                        1.3
# 38                        0.3
# 39                        0.1

# %% [markdown]
# Add Date column to the dataframe

# %%
df.insert (0, 'Date', date)

# %%
df
# Out:
#           Date             River Basin   Tributory/River  \
# 0   2023-06-02     Kelani Ganga(RB 01)      Kelani Ganga
# 1   2023-06-02     Kelani Ganga(RB 01)      Kelani Ganga
# 2   2023-06-02     Kelani Ganga(RB 01)      Kelani Ganga
# 3   2023-06-02     Kelani Ganga(RB 01)      Kelani Ganga
# 4   2023-06-02     Kelani Ganga(RB 01)      Gurugoda Oya
# 5   2023-06-02     Kelani Ganga(RB 01)  Seethawaka Ganga
# 6   2023-06-02     Kelani Ganga(RB 01)     Kehelgamu Oya
# 7   2023-06-02       Kalu Ganga(RB 03)        Kalu Ganga
# 8   2023-06-02       Kalu Ganga(RB 03)        Kalu Ganga
# 9   2023-06-02       Kalu Ganga(RB 03)        Kalu Ganga
# 10  2023-06-02       Kalu Ganga(RB 03)      Maguru Ganga
# 11  2023-06-02       Kalu Ganga(RB 03)        Kuda Ganga
# 12  2023-06-02        Gin Ganga(RB 09)         Gin Ganga
# 13  2023-06-02        Gin Ganga(RB 09)         Gin Ganga
# 14  2023-06-02    Nilwala Ganga(RB 12)     Nilwala Ganga
# 15  2023-06-02    Nilwala Ganga(RB 12)     Nilwala Ganga
# 16  2023-06-02    Nilwala Ganga(RB 12)     Nilwala Ganga
# 17  2023-06-02    Nilwala Ganga(RB 12)    Urubokka Ganga
# 18  2023-06-02     Walawe Ganga(RB 18)      Walawe Ganga
# 19  2023-06-02      Kirindi Oya(RB 22)       Kirindi Oya
# 20  2023-06-02      Kirindi Oya(RB 22)       Kirindi Oya
# 21  2023-06-02      Kirindi Oya(RB 22)          Kuda Oya
# 22  2023-06-02      Menik Ganga(RB 26)       Menik Ganga
# 23  2023-06-02    Kumbukkan Oya(RB 31)     Kumbukkan Oya
# 24  2023-06-02         Heda Oya(RB 36)          Heda Oya
# 25  2023-06-02       Maduru Oya(RB 54)        Maduru Oya
# 26  2023-06-02   Mahaweli Ganga(RB 60)    Mahaweli Ganga
# 27  2023-06-02   Mahaweli Ganga(RB 60)    Mahaweli Ganga
# 28  2023-06-02   Mahaweli Ganga(RB 60)    Mahaweli Ganga
# 29  2023-06-02   Mahaweli Ganga(RB 60)    Mahaweli Ganga
# 30  2023-06-02   Mahaweli Ganga(RB 60)    Mahaweli Ganga
# 31  2023-06-02   Mahaweli Ganga(RB 60)        Badulu Oya
# 32  2023-06-02          Yan Oya(RB 67)           Yan Oya
# 33  2023-06-02          Maa Oya(RB 69)        Mukunu Oya
# 34  2023-06-02     Malwathu Oya(RB 90)      Malwathu Oya
# 35  2023-06-02          Mee Oya(RB 95)           Mee Oya
# 36  2023-06-02       Deduru Oya(RB 99)        Deduru Oya
# 37  2023-06-02        Maha Oya(RB 102)          Maha Oya
# 38  2023-06-02        Maha Oya(RB 102)          Maha Oya
# 39  2023-06-02  Attanagalu Oya(RB 103)    Attanagalu Oya
#
#                      Station Unit Alert Level Minor Flood Level  \
# 0                  N' Street   ft        4.00              5.00
# 1                   Hanwella    m        7.00              8.00
# 2                 Glencourse    m       15.00             16.50
# 3                  Kitulgala    m        3.00              4.00
# 4                  Holombuwa    m        3.00              3.40
# 5               Deraniyagala    m        4.80              5.80
# 6                    Norwood    m        1.50              3.00
# 7                  Putupaula    m        3.00              4.00
# 8                   Ellagawa    m       10.00             10.70
# 9                  Ratnapura    m        5.20              7.50
# 10                    Magura    m        4.00              6.00
# 11  Kalawellawa (Millakanda)    m        5.00              6.50
# 12                  Tawalama    m        4.00              6.00
# 13                 Baddegama    m        3.50              4.00
# 14              Thalgahagoda    m        1.40              1.70
# 15                Panadugama    m        5.00              6.00
# 16               Pitabeddara    m        4.00              5.00
# 17                     Urawa    m        2.50              4.00
# 18                Moraketiya    m        1.80              3.50
# 19               Tanamalwila    m        4.00              5.00
# 20                 Wellawaya    m        4.40              5.40
# 21                  Kuda Oya    m        6.90              8.40
# 22               Katharagama    m        4.00              4.60
# 23                   Nakkala    m        5.00              6.00
# 24            Siyambalanduwa    m        4.50              6.00
# 25              Padiyatalawa    m        4.00              4.50
# 26        Manampitiya ( Old)    m        3.50              5.00
# 27        Manampitiya (HMIS)    m        4.65              6.15
# 28               Weragantota    m        5.00              6.00
# 29                Peradeniya    m        5.00              7.00
# 30              Nawalapitiya    m        3.50              5.00
# 31                   Taldena    m        3.00              4.00
# 32               Horowpatana    m        6.00              7.50
# 33                  Yakawewa    m        4.00              5.00
# 34               Tantirimale    m        5.00              6.80
# 35                 Galgamuwa    m        4.84              5.94
# 36               Moragaswewa    m           -                 -
# 37                 Badalgama    m        5.00              6.20
# 38                  Giriulla    m        5.50              6.50
# 39                  Dunamale    m        3.30              4.40
#
#    Major Flood Level  Water Level at 8:00 am  Water Level at 9:00 am  \
# 0               7.00                    1.20                    1.50
# 1              10.00                    3.07                    3.21
# 2              19.00                   12.03                   11.77
# 3               6.00                    1.65                    1.54
# 4               5.00                    0.23                    0.23
# 5               6.40                    1.46                    1.37
# 6               4.50                    0.60                    0.59
# 7               5.00                    1.60                    1.69
# 8              12.20                    8.01                    8.12
# 9               9.50                    5.25                    5.16
# 10              7.50                    5.91                    5.97
# 11              8.00                    5.15                    5.27
# 12              7.50                    5.47                    5.58
# 13              5.00                    3.53                    3.55
# 14              2.80                    1.38                    1.40
# 15              7.50                    6.18                    6.05
# 16              6.50                    2.00                    2.05
# 17              6.00                    1.70                    1.66
# 18              5.00                    0.85                    0.86
# 19              5.50                    0.38                    0.37
# 20              5.90                    0.72                    0.72
# 21              8.80                    1.23                    1.22
# 22              6.50                   -0.19                   -0.19
# 23              7.50                    0.84                    0.83
# 24              7.00                    0.48                    0.48
# 25              6.00                    0.29                    0.29
# 26              6.00                   -0.72                   -0.72
# 27              7.15                    0.42                    0.42
# 28              8.00                   -2.64                   -2.67
# 29              9.00                    1.12                    1.18
# 30              6.00                    0.84                    0.88
# 31              5.00                    0.47                    0.47
# 32             10.50                    1.55                    1.55
# 33              6.00                    0.49                    0.49
# 34              7.80                    1.13                    1.13
# 35              8.00                    0.02                    0.02
# 36                 -                    0.32                    0.32
# 37              9.60                    1.87                    1.87
# 38              7.50                    0.82                    0.82
# 39              5.50                    0.70                    0.70
#
#         Remarks Water Level Rising or Falling  24 Hr RF in mm at 8.30 am
# 0        Normal                        Stable                        0.0
# 1        Normal                        Stable                       16.2
# 2        Normal                        Stable                       26.5
# 3        Normal                        Stable                       25.6
# 4        Normal                        Stable                        2.5
# 5        Normal                        Stable                      175.8
# 6        Normal                        Stable                        5.5
# 7        Normal                        Stable                       15.0
# 8        Normal                        Stable                      100.7
# 9        Normal                        Stable                      141.3
# 10        Alert                        Rising                       49.0
# 11        Alert                        Rising                       15.5
# 12        Alert                        Rising                       77.9
# 13        Alert                        Rising                       45.7
# 14        Alert                        Rising                       38.4
# 15  Minor Flood                       Falling                        7.5
# 16       Normal                        Stable                      132.3
# 17       Normal                        Stable                       42.7
# 18       Normal                        Stable                        9.5
# 19       Normal                        Stable                        0.0
# 20       Normal                        Stable                        0.0
# 21       Normal                        Stable                        0.0
# 22       Normal                        Stable                        0.0
# 23       Normal                        Stable                        0.0
# 24       Normal                        Stable                        0.0
# 25       Normal                        Stable                        0.0
# 26       Normal                        Stable                        0.0
# 27       Normal                        Stable                        0.0
# 28       Normal                        Stable                        0.0
# 29       Normal                        Stable                        0.0
# 30       Normal                        Stable                        0.0
# 31       Normal                        Stable                        0.0
# 32       Normal                        Stable                        0.0
# 33       Normal                        Stable                        0.0
# 34       Normal                        Stable                        0.0
# 35       Normal                        Stable                        0.0
# 36       Normal                        Stable                        0.0
# 37       Normal                        Stable                        1.3
# 38       Normal                        Stable                        0.3
# 39       Normal                        Stable                        0.1

# %% [markdown]
# Replace the "-" with 0 in numerical columns

# %%
water_level_columns = ['Alert Level', 'Minor Flood Level', 'Major Flood Level', 'Water Level at 8:00 am', 'Water Level at 9:00 am']
df[water_level_columns] = df[water_level_columns].replace('-',pd.NA)
df[water_level_columns] = df[water_level_columns].fillna(0)
df
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_14060\2121928992.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[water_level_columns] = df[water_level_columns].replace('-',pd.NA)
# C:\Users\User\AppData\Local\Temp\ipykernel_14060\2121928992.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[water_level_columns] = df[water_level_columns].fillna(0)
#           Date             River Basin   Tributory/River  \
# 0   2023-06-02     Kelani Ganga(RB 01)      Kelani Ganga
# 1   2023-06-02     Kelani Ganga(RB 01)      Kelani Ganga
# 2   2023-06-02     Kelani Ganga(RB 01)      Kelani Ganga
# 3   2023-06-02     Kelani Ganga(RB 01)      Kelani Ganga
# 4   2023-06-02     Kelani Ganga(RB 01)      Gurugoda Oya
# 5   2023-06-02     Kelani Ganga(RB 01)  Seethawaka Ganga
# 6   2023-06-02     Kelani Ganga(RB 01)     Kehelgamu Oya
# 7   2023-06-02       Kalu Ganga(RB 03)        Kalu Ganga
# 8   2023-06-02       Kalu Ganga(RB 03)        Kalu Ganga
# 9   2023-06-02       Kalu Ganga(RB 03)        Kalu Ganga
# 10  2023-06-02       Kalu Ganga(RB 03)      Maguru Ganga
# 11  2023-06-02       Kalu Ganga(RB 03)        Kuda Ganga
# 12  2023-06-02        Gin Ganga(RB 09)         Gin Ganga
# 13  2023-06-02        Gin Ganga(RB 09)         Gin Ganga
# 14  2023-06-02    Nilwala Ganga(RB 12)     Nilwala Ganga
# 15  2023-06-02    Nilwala Ganga(RB 12)     Nilwala Ganga
# 16  2023-06-02    Nilwala Ganga(RB 12)     Nilwala Ganga
# 17  2023-06-02    Nilwala Ganga(RB 12)    Urubokka Ganga
# 18  2023-06-02     Walawe Ganga(RB 18)      Walawe Ganga
# 19  2023-06-02      Kirindi Oya(RB 22)       Kirindi Oya
# 20  2023-06-02      Kirindi Oya(RB 22)       Kirindi Oya
# 21  2023-06-02      Kirindi Oya(RB 22)          Kuda Oya
# 22  2023-06-02      Menik Ganga(RB 26)       Menik Ganga
# 23  2023-06-02    Kumbukkan Oya(RB 31)     Kumbukkan Oya
# 24  2023-06-02         Heda Oya(RB 36)          Heda Oya
# 25  2023-06-02       Maduru Oya(RB 54)        Maduru Oya
# 26  2023-06-02   Mahaweli Ganga(RB 60)    Mahaweli Ganga
# 27  2023-06-02   Mahaweli Ganga(RB 60)    Mahaweli Ganga
# 28  2023-06-02   Mahaweli Ganga(RB 60)    Mahaweli Ganga
# 29  2023-06-02   Mahaweli Ganga(RB 60)    Mahaweli Ganga
# 30  2023-06-02   Mahaweli Ganga(RB 60)    Mahaweli Ganga
# 31  2023-06-02   Mahaweli Ganga(RB 60)        Badulu Oya
# 32  2023-06-02          Yan Oya(RB 67)           Yan Oya
# 33  2023-06-02          Maa Oya(RB 69)        Mukunu Oya
# 34  2023-06-02     Malwathu Oya(RB 90)      Malwathu Oya
# 35  2023-06-02          Mee Oya(RB 95)           Mee Oya
# 36  2023-06-02       Deduru Oya(RB 99)        Deduru Oya
# 37  2023-06-02        Maha Oya(RB 102)          Maha Oya
# 38  2023-06-02        Maha Oya(RB 102)          Maha Oya
# 39  2023-06-02  Attanagalu Oya(RB 103)    Attanagalu Oya
#
#                      Station Unit Alert Level Minor Flood Level  \
# 0                  N' Street   ft        4.00              5.00
# 1                   Hanwella    m        7.00              8.00
# 2                 Glencourse    m       15.00             16.50
# 3                  Kitulgala    m        3.00              4.00
# 4                  Holombuwa    m        3.00              3.40
# 5               Deraniyagala    m        4.80              5.80
# 6                    Norwood    m        1.50              3.00
# 7                  Putupaula    m        3.00              4.00
# 8                   Ellagawa    m       10.00             10.70
# 9                  Ratnapura    m        5.20              7.50
# 10                    Magura    m        4.00              6.00
# 11  Kalawellawa (Millakanda)    m        5.00              6.50
# 12                  Tawalama    m        4.00              6.00
# 13                 Baddegama    m        3.50              4.00
# 14              Thalgahagoda    m        1.40              1.70
# 15                Panadugama    m        5.00              6.00
# 16               Pitabeddara    m        4.00              5.00
# 17                     Urawa    m        2.50              4.00
# 18                Moraketiya    m        1.80              3.50
# 19               Tanamalwila    m        4.00              5.00
# 20                 Wellawaya    m        4.40              5.40
# 21                  Kuda Oya    m        6.90              8.40
# 22               Katharagama    m        4.00              4.60
# 23                   Nakkala    m        5.00              6.00
# 24            Siyambalanduwa    m        4.50              6.00
# 25              Padiyatalawa    m        4.00              4.50
# 26        Manampitiya ( Old)    m        3.50              5.00
# 27        Manampitiya (HMIS)    m        4.65              6.15
# 28               Weragantota    m        5.00              6.00
# 29                Peradeniya    m        5.00              7.00
# 30              Nawalapitiya    m        3.50              5.00
# 31                   Taldena    m        3.00              4.00
# 32               Horowpatana    m        6.00              7.50
# 33                  Yakawewa    m        4.00              5.00
# 34               Tantirimale    m        5.00              6.80
# 35                 Galgamuwa    m        4.84              5.94
# 36               Moragaswewa    m           0                 0
# 37                 Badalgama    m        5.00              6.20
# 38                  Giriulla    m        5.50              6.50
# 39                  Dunamale    m        3.30              4.40
#
#    Major Flood Level  Water Level at 8:00 am  Water Level at 9:00 am  \
# 0               7.00                    1.20                    1.50
# 1              10.00                    3.07                    3.21
# 2              19.00                   12.03                   11.77
# 3               6.00                    1.65                    1.54
# 4               5.00                    0.23                    0.23
# 5               6.40                    1.46                    1.37
# 6               4.50                    0.60                    0.59
# 7               5.00                    1.60                    1.69
# 8              12.20                    8.01                    8.12
# 9               9.50                    5.25                    5.16
# 10              7.50                    5.91                    5.97
# 11              8.00                    5.15                    5.27
# 12              7.50                    5.47                    5.58
# 13              5.00                    3.53                    3.55
# 14              2.80                    1.38                    1.40
# 15              7.50                    6.18                    6.05
# 16              6.50                    2.00                    2.05
# 17              6.00                    1.70                    1.66
# 18              5.00                    0.85                    0.86
# 19              5.50                    0.38                    0.37
# 20              5.90                    0.72                    0.72
# 21              8.80                    1.23                    1.22
# 22              6.50                   -0.19                   -0.19
# 23              7.50                    0.84                    0.83
# 24              7.00                    0.48                    0.48
# 25              6.00                    0.29                    0.29
# 26              6.00                   -0.72                   -0.72
# 27              7.15                    0.42                    0.42
# 28              8.00                   -2.64                   -2.67
# 29              9.00                    1.12                    1.18
# 30              6.00                    0.84                    0.88
# 31              5.00                    0.47                    0.47
# 32             10.50                    1.55                    1.55
# 33              6.00                    0.49                    0.49
# 34              7.80                    1.13                    1.13
# 35              8.00                    0.02                    0.02
# 36                 0                    0.32                    0.32
# 37              9.60                    1.87                    1.87
# 38              7.50                    0.82                    0.82
# 39              5.50                    0.70                    0.70
#
#         Remarks Water Level Rising or Falling  24 Hr RF in mm at 8.30 am
# 0        Normal                        Stable                        0.0
# 1        Normal                        Stable                       16.2
# 2        Normal                        Stable                       26.5
# 3        Normal                        Stable                       25.6
# 4        Normal                        Stable                        2.5
# 5        Normal                        Stable                      175.8
# 6        Normal                        Stable                        5.5
# 7        Normal                        Stable                       15.0
# 8        Normal                        Stable                      100.7
# 9        Normal                        Stable                      141.3
# 10        Alert                        Rising                       49.0
# 11        Alert                        Rising                       15.5
# 12        Alert                        Rising                       77.9
# 13        Alert                        Rising                       45.7
# 14        Alert                        Rising                       38.4
# 15  Minor Flood                       Falling                        7.5
# 16       Normal                        Stable                      132.3
# 17       Normal                        Stable                       42.7
# 18       Normal                        Stable                        9.5
# 19       Normal                        Stable                        0.0
# 20       Normal                        Stable                        0.0
# 21       Normal                        Stable                        0.0
# 22       Normal                        Stable                        0.0
# 23       Normal                        Stable                        0.0
# 24       Normal                        Stable                        0.0
# 25       Normal                        Stable                        0.0
# 26       Normal                        Stable                        0.0
# 27       Normal                        Stable                        0.0
# 28       Normal                        Stable                        0.0
# 29       Normal                        Stable                        0.0
# 30       Normal                        Stable                        0.0
# 31       Normal                        Stable                        0.0
# 32       Normal                        Stable                        0.0
# 33       Normal                        Stable                        0.0
# 34       Normal                        Stable                        0.0
# 35       Normal                        Stable                        0.0
# 36       Normal                        Stable                        0.0
# 37       Normal                        Stable                        1.3
# 38       Normal                        Stable                        0.3
# 39       Normal                        Stable                        0.1

# %% [markdown]
# Convert the unit of Station "N' Street" from feet to meters

# %%
row_condition = (df['Station'] == 'N\' Street')
df.loc[row_condition, 'Unit'] = 'm'

df[water_level_columns] = df[water_level_columns].astype(float)
df.loc[row_condition, water_level_columns] = (df.loc[row_condition, water_level_columns] * 0.3048).round(2)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_14060\1321710840.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[water_level_columns] = df[water_level_columns].astype(float)

# %%
df
# Out:
#           Date             River Basin   Tributory/River  \
# 0   2023-06-02     Kelani Ganga(RB 01)      Kelani Ganga
# 1   2023-06-02     Kelani Ganga(RB 01)      Kelani Ganga
# 2   2023-06-02     Kelani Ganga(RB 01)      Kelani Ganga
# 3   2023-06-02     Kelani Ganga(RB 01)      Kelani Ganga
# 4   2023-06-02     Kelani Ganga(RB 01)      Gurugoda Oya
# 5   2023-06-02     Kelani Ganga(RB 01)  Seethawaka Ganga
# 6   2023-06-02     Kelani Ganga(RB 01)     Kehelgamu Oya
# 7   2023-06-02       Kalu Ganga(RB 03)        Kalu Ganga
# 8   2023-06-02       Kalu Ganga(RB 03)        Kalu Ganga
# 9   2023-06-02       Kalu Ganga(RB 03)        Kalu Ganga
# 10  2023-06-02       Kalu Ganga(RB 03)      Maguru Ganga
# 11  2023-06-02       Kalu Ganga(RB 03)        Kuda Ganga
# 12  2023-06-02        Gin Ganga(RB 09)         Gin Ganga
# 13  2023-06-02        Gin Ganga(RB 09)         Gin Ganga
# 14  2023-06-02    Nilwala Ganga(RB 12)     Nilwala Ganga
# 15  2023-06-02    Nilwala Ganga(RB 12)     Nilwala Ganga
# 16  2023-06-02    Nilwala Ganga(RB 12)     Nilwala Ganga
# 17  2023-06-02    Nilwala Ganga(RB 12)    Urubokka Ganga
# 18  2023-06-02     Walawe Ganga(RB 18)      Walawe Ganga
# 19  2023-06-02      Kirindi Oya(RB 22)       Kirindi Oya
# 20  2023-06-02      Kirindi Oya(RB 22)       Kirindi Oya
# 21  2023-06-02      Kirindi Oya(RB 22)          Kuda Oya
# 22  2023-06-02      Menik Ganga(RB 26)       Menik Ganga
# 23  2023-06-02    Kumbukkan Oya(RB 31)     Kumbukkan Oya
# 24  2023-06-02         Heda Oya(RB 36)          Heda Oya
# 25  2023-06-02       Maduru Oya(RB 54)        Maduru Oya
# 26  2023-06-02   Mahaweli Ganga(RB 60)    Mahaweli Ganga
# 27  2023-06-02   Mahaweli Ganga(RB 60)    Mahaweli Ganga
# 28  2023-06-02   Mahaweli Ganga(RB 60)    Mahaweli Ganga
# 29  2023-06-02   Mahaweli Ganga(RB 60)    Mahaweli Ganga
# 30  2023-06-02   Mahaweli Ganga(RB 60)    Mahaweli Ganga
# 31  2023-06-02   Mahaweli Ganga(RB 60)        Badulu Oya
# 32  2023-06-02          Yan Oya(RB 67)           Yan Oya
# 33  2023-06-02          Maa Oya(RB 69)        Mukunu Oya
# 34  2023-06-02     Malwathu Oya(RB 90)      Malwathu Oya
# 35  2023-06-02          Mee Oya(RB 95)           Mee Oya
# 36  2023-06-02       Deduru Oya(RB 99)        Deduru Oya
# 37  2023-06-02        Maha Oya(RB 102)          Maha Oya
# 38  2023-06-02        Maha Oya(RB 102)          Maha Oya
# 39  2023-06-02  Attanagalu Oya(RB 103)    Attanagalu Oya
#
#                      Station Unit  Alert Level  Minor Flood Level  \
# 0                  N' Street    m         1.22               1.52
# 1                   Hanwella    m         7.00               8.00
# 2                 Glencourse    m        15.00              16.50
# 3                  Kitulgala    m         3.00               4.00
# 4                  Holombuwa    m         3.00               3.40
# 5               Deraniyagala    m         4.80               5.80
# 6                    Norwood    m         1.50               3.00
# 7                  Putupaula    m         3.00               4.00
# 8                   Ellagawa    m        10.00              10.70
# 9                  Ratnapura    m         5.20               7.50
# 10                    Magura    m         4.00               6.00
# 11  Kalawellawa (Millakanda)    m         5.00               6.50
# 12                  Tawalama    m         4.00               6.00
# 13                 Baddegama    m         3.50               4.00
# 14              Thalgahagoda    m         1.40               1.70
# 15                Panadugama    m         5.00               6.00
# 16               Pitabeddara    m         4.00               5.00
# 17                     Urawa    m         2.50               4.00
# 18                Moraketiya    m         1.80               3.50
# 19               Tanamalwila    m         4.00               5.00
# 20                 Wellawaya    m         4.40               5.40
# 21                  Kuda Oya    m         6.90               8.40
# 22               Katharagama    m         4.00               4.60
# 23                   Nakkala    m         5.00               6.00
# 24            Siyambalanduwa    m         4.50               6.00
# 25              Padiyatalawa    m         4.00               4.50
# 26        Manampitiya ( Old)    m         3.50               5.00
# 27        Manampitiya (HMIS)    m         4.65               6.15
# 28               Weragantota    m         5.00               6.00
# 29                Peradeniya    m         5.00               7.00
# 30              Nawalapitiya    m         3.50               5.00
# 31                   Taldena    m         3.00               4.00
# 32               Horowpatana    m         6.00               7.50
# 33                  Yakawewa    m         4.00               5.00
# 34               Tantirimale    m         5.00               6.80
# 35                 Galgamuwa    m         4.84               5.94
# 36               Moragaswewa    m         0.00               0.00
# 37                 Badalgama    m         5.00               6.20
# 38                  Giriulla    m         5.50               6.50
# 39                  Dunamale    m         3.30               4.40
#
#     Major Flood Level  Water Level at 8:00 am  Water Level at 9:00 am  \
# 0                2.13                    0.37                    0.46
# 1               10.00                    3.07                    3.21
# 2               19.00                   12.03                   11.77
# 3                6.00                    1.65                    1.54
# 4                5.00                    0.23                    0.23
# 5                6.40                    1.46                    1.37
# 6                4.50                    0.60                    0.59
# 7                5.00                    1.60                    1.69
# 8               12.20                    8.01                    8.12
# 9                9.50                    5.25                    5.16
# 10               7.50                    5.91                    5.97
# 11               8.00                    5.15                    5.27
# 12               7.50                    5.47                    5.58
# 13               5.00                    3.53                    3.55
# 14               2.80                    1.38                    1.40
# 15               7.50                    6.18                    6.05
# 16               6.50                    2.00                    2.05
# 17               6.00                    1.70                    1.66
# 18               5.00                    0.85                    0.86
# 19               5.50                    0.38                    0.37
# 20               5.90                    0.72                    0.72
# 21               8.80                    1.23                    1.22
# 22               6.50                   -0.19                   -0.19
# 23               7.50                    0.84                    0.83
# 24               7.00                    0.48                    0.48
# 25               6.00                    0.29                    0.29
# 26               6.00                   -0.72                   -0.72
# 27               7.15                    0.42                    0.42
# 28               8.00                   -2.64                   -2.67
# 29               9.00                    1.12                    1.18
# 30               6.00                    0.84                    0.88
# 31               5.00                    0.47                    0.47
# 32              10.50                    1.55                    1.55
# 33               6.00                    0.49                    0.49
# 34               7.80                    1.13                    1.13
# 35               8.00                    0.02                    0.02
# 36               0.00                    0.32                    0.32
# 37               9.60                    1.87                    1.87
# 38               7.50                    0.82                    0.82
# 39               5.50                    0.70                    0.70
#
#         Remarks Water Level Rising or Falling  24 Hr RF in mm at 8.30 am
# 0        Normal                        Stable                        0.0
# 1        Normal                        Stable                       16.2
# 2        Normal                        Stable                       26.5
# 3        Normal                        Stable                       25.6
# 4        Normal                        Stable                        2.5
# 5        Normal                        Stable                      175.8
# 6        Normal                        Stable                        5.5
# 7        Normal                        Stable                       15.0
# 8        Normal                        Stable                      100.7
# 9        Normal                        Stable                      141.3
# 10        Alert                        Rising                       49.0
# 11        Alert                        Rising                       15.5
# 12        Alert                        Rising                       77.9
# 13        Alert                        Rising                       45.7
# 14        Alert                        Rising                       38.4
# 15  Minor Flood                       Falling                        7.5
# 16       Normal                        Stable                      132.3
# 17       Normal                        Stable                       42.7
# 18       Normal                        Stable                        9.5
# 19       Normal                        Stable                        0.0
# 20       Normal                        Stable                        0.0
# 21       Normal                        Stable                        0.0
# 22       Normal                        Stable                        0.0
# 23       Normal                        Stable                        0.0
# 24       Normal                        Stable                        0.0
# 25       Normal                        Stable                        0.0
# 26       Normal                        Stable                        0.0
# 27       Normal                        Stable                        0.0
# 28       Normal                        Stable                        0.0
# 29       Normal                        Stable                        0.0
# 30       Normal                        Stable                        0.0
# 31       Normal                        Stable                        0.0
# 32       Normal                        Stable                        0.0
# 33       Normal                        Stable                        0.0
# 34       Normal                        Stable                        0.0
# 35       Normal                        Stable                        0.0
# 36       Normal                        Stable                        0.0
# 37       Normal                        Stable                        1.3
# 38       Normal                        Stable                        0.3
# 39       Normal                        Stable                        0.1

# %% [markdown]
# Add new columns for Latitude and Longitude of stations

# %%
coordinates = {'N\' Street': {'Latitude': 6.9271, 'Longitude': 79.8612},
               'Hanwella': {'Latitude': 6.897834, 'Longitude': 80.081429},
               'Glencourse': {'Latitude': 6.966667, 'Longitude':  80.183333},
               'Kitulgala': {'Latitude': 6.99722, 'Longitude': 80.41111},
               'Holombuwa': {'Latitude': 7.1965, 'Longitude': 80.2739},
               'Deraniyagala': {'Latitude': 6.9349, 'Longitude': 80.3380},
               'Norwood': {'Latitude': 6.8384, 'Longitude': 80.6147},
               'Putupaula': {'Latitude': 6.6110, 'Longitude': 80.0616},
               'Ellagawa': {'Latitude': 6.7444, 'Longitude': 80.2070},
               'Ratnapura': {'Latitude': 6.7056, 'Longitude': 80.3847},
               'Magura': {'Latitude': 6.4943, 'Longitude': 80.2344},
               'Kalawellawa\r(Millakanda)': {'Latitude': 6.64263, 'Longitude': 80.17548},
               'Kalawellawa (Millakanda)': {'Latitude': 6.64263, 'Longitude': 80.17548},
               'Kalawellawa(Millakanda)': {'Latitude': 6.64263, 'Longitude': 80.17548},
               'Kalawellawa': {'Latitude': 6.64263, 'Longitude': 80.17548},
               'Baddegama': {'Latitude': 6.1688, 'Longitude': 80.1794},
               'Tawalama': {'Latitude': 6.3347, 'Longitude': 80.3422},
               'Thalgahagoda': {'Latitude': 7.5036, 'Longitude': 80.5952},
               'Panadugama': {'Latitude': 6.1092, 'Longitude': 80.4841},
               'Pitabeddara': {'Latitude': 6.2071, 'Longitude': 80.4632},
               'Urawa': {'Latitude': 6.250, 'Longitude': 80.567},
               'Moraketiya': {'Latitude': 6.3408, 'Longitude': 80.8959},
               'Tanamalwila': {'Latitude': 6.4347, 'Longitude': 81.1308},
               'Wellawaya': {'Latitude': 6.7377, 'Longitude': 81.1031},
               'Kuda Oya': {'Latitude': 6.5345, 'Longitude': 81.1224},
               'Katharagama': {'Latitude': 6.4135, 'Longitude': 81.3326},
               'Nakkala': {'Latitude': 6.8900, 'Longitude': 81.2984},
               'Siyambalanduwa': {'Latitude': 6.9065, 'Longitude': 81.5610},
               'Padiyatalawa': {'Latitude': 7.3925, 'Longitude': 81.2436},
               'Manampitiya (Old)': {'Latitude': 7.9136, 'Longitude': 81.0889},
               'Manampitiya ( Old)': {'Latitude': 7.9136, 'Longitude': 81.0889},
               'Manampitiya (HMIS)': {'Latitude': 7.9051, 'Longitude': 81.1313},
               'Weragantota': {'Latitude': 7.3299, 'Longitude': 80.9857},
               'Peradeniya': {'Latitude': 7.2699, 'Longitude': 80.5938},
               'Nawalapitiya': {'Latitude': 7.0548, 'Longitude': 80.5335},
               'Taldena': {'Latitude': 7.0926, 'Longitude': 81.0495},
               'Horowpatana': {'Latitude': 8.6181, 'Longitude': 80.8294},
               'Yakawewa': {'Latitude': 8.7261, 'Longitude': 80.6750},
               'Tantirimale': {'Latitude': 8.5723, 'Longitude': 80.2572},
               'Galgamuwa': {'Latitude': 7.9865, 'Longitude': 80.2879},
               'Moragaswewa': {'Latitude': 8.0327, 'Longitude': 80.7741},
               'Badalgama': {'Latitude': 7.2887, 'Longitude': 79.9808},
               'Giriulla': {'Latitude': 7.3318, 'Longitude': 80.1233},
               'Dunamale': {'Latitude': 7.8774, 'Longitude': 80.7003},
               }

# Add new columns for Latitude and Longitude
df['Latitude'] = df['Station'].map(lambda station: coordinates.get(station, {}).get('Latitude'))
df['Longitude'] = df['Station'].map(lambda station: coordinates.get(station, {}).get('Longitude'))
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_14060\738545427.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Latitude'] = df['Station'].map(lambda station: coordinates.get(station, {}).get('Latitude'))
# C:\Users\User\AppData\Local\Temp\ipykernel_14060\738545427.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Longitude'] = df['Station'].map(lambda station: coordinates.get(station, {}).get('Longitude'))

# %%
df
# Out:
#           Date             River Basin   Tributory/River  \
# 0   2023-06-02     Kelani Ganga(RB 01)      Kelani Ganga
# 1   2023-06-02     Kelani Ganga(RB 01)      Kelani Ganga
# 2   2023-06-02     Kelani Ganga(RB 01)      Kelani Ganga
# 3   2023-06-02     Kelani Ganga(RB 01)      Kelani Ganga
# 4   2023-06-02     Kelani Ganga(RB 01)      Gurugoda Oya
# 5   2023-06-02     Kelani Ganga(RB 01)  Seethawaka Ganga
# 6   2023-06-02     Kelani Ganga(RB 01)     Kehelgamu Oya
# 7   2023-06-02       Kalu Ganga(RB 03)        Kalu Ganga
# 8   2023-06-02       Kalu Ganga(RB 03)        Kalu Ganga
# 9   2023-06-02       Kalu Ganga(RB 03)        Kalu Ganga
# 10  2023-06-02       Kalu Ganga(RB 03)      Maguru Ganga
# 11  2023-06-02       Kalu Ganga(RB 03)        Kuda Ganga
# 12  2023-06-02        Gin Ganga(RB 09)         Gin Ganga
# 13  2023-06-02        Gin Ganga(RB 09)         Gin Ganga
# 14  2023-06-02    Nilwala Ganga(RB 12)     Nilwala Ganga
# 15  2023-06-02    Nilwala Ganga(RB 12)     Nilwala Ganga
# 16  2023-06-02    Nilwala Ganga(RB 12)     Nilwala Ganga
# 17  2023-06-02    Nilwala Ganga(RB 12)    Urubokka Ganga
# 18  2023-06-02     Walawe Ganga(RB 18)      Walawe Ganga
# 19  2023-06-02      Kirindi Oya(RB 22)       Kirindi Oya
# 20  2023-06-02      Kirindi Oya(RB 22)       Kirindi Oya
# 21  2023-06-02      Kirindi Oya(RB 22)          Kuda Oya
# 22  2023-06-02      Menik Ganga(RB 26)       Menik Ganga
# 23  2023-06-02    Kumbukkan Oya(RB 31)     Kumbukkan Oya
# 24  2023-06-02         Heda Oya(RB 36)          Heda Oya
# 25  2023-06-02       Maduru Oya(RB 54)        Maduru Oya
# 26  2023-06-02   Mahaweli Ganga(RB 60)    Mahaweli Ganga
# 27  2023-06-02   Mahaweli Ganga(RB 60)    Mahaweli Ganga
# 28  2023-06-02   Mahaweli Ganga(RB 60)    Mahaweli Ganga
# 29  2023-06-02   Mahaweli Ganga(RB 60)    Mahaweli Ganga
# 30  2023-06-02   Mahaweli Ganga(RB 60)    Mahaweli Ganga
# 31  2023-06-02   Mahaweli Ganga(RB 60)        Badulu Oya
# 32  2023-06-02          Yan Oya(RB 67)           Yan Oya
# 33  2023-06-02          Maa Oya(RB 69)        Mukunu Oya
# 34  2023-06-02     Malwathu Oya(RB 90)      Malwathu Oya
# 35  2023-06-02          Mee Oya(RB 95)           Mee Oya
# 36  2023-06-02       Deduru Oya(RB 99)        Deduru Oya
# 37  2023-06-02        Maha Oya(RB 102)          Maha Oya
# 38  2023-06-02        Maha Oya(RB 102)          Maha Oya
# 39  2023-06-02  Attanagalu Oya(RB 103)    Attanagalu Oya
#
#                      Station Unit  Alert Level  Minor Flood Level  \
# 0                  N' Street    m         1.22               1.52
# 1                   Hanwella    m         7.00               8.00
# 2                 Glencourse    m        15.00              16.50
# 3                  Kitulgala    m         3.00               4.00
# 4                  Holombuwa    m         3.00               3.40
# 5               Deraniyagala    m         4.80               5.80
# 6                    Norwood    m         1.50               3.00
# 7                  Putupaula    m         3.00               4.00
# 8                   Ellagawa    m        10.00              10.70
# 9                  Ratnapura    m         5.20               7.50
# 10                    Magura    m         4.00               6.00
# 11  Kalawellawa (Millakanda)    m         5.00               6.50
# 12                  Tawalama    m         4.00               6.00
# 13                 Baddegama    m         3.50               4.00
# 14              Thalgahagoda    m         1.40               1.70
# 15                Panadugama    m         5.00               6.00
# 16               Pitabeddara    m         4.00               5.00
# 17                     Urawa    m         2.50               4.00
# 18                Moraketiya    m         1.80               3.50
# 19               Tanamalwila    m         4.00               5.00
# 20                 Wellawaya    m         4.40               5.40
# 21                  Kuda Oya    m         6.90               8.40
# 22               Katharagama    m         4.00               4.60
# 23                   Nakkala    m         5.00               6.00
# 24            Siyambalanduwa    m         4.50               6.00
# 25              Padiyatalawa    m         4.00               4.50
# 26        Manampitiya ( Old)    m         3.50               5.00
# 27        Manampitiya (HMIS)    m         4.65               6.15
# 28               Weragantota    m         5.00               6.00
# 29                Peradeniya    m         5.00               7.00
# 30              Nawalapitiya    m         3.50               5.00
# 31                   Taldena    m         3.00               4.00
# 32               Horowpatana    m         6.00               7.50
# 33                  Yakawewa    m         4.00               5.00
# 34               Tantirimale    m         5.00               6.80
# 35                 Galgamuwa    m         4.84               5.94
# 36               Moragaswewa    m         0.00               0.00
# 37                 Badalgama    m         5.00               6.20
# 38                  Giriulla    m         5.50               6.50
# 39                  Dunamale    m         3.30               4.40
#
#     Major Flood Level  Water Level at 8:00 am  Water Level at 9:00 am  \
# 0                2.13                    0.37                    0.46
# 1               10.00                    3.07                    3.21
# 2               19.00                   12.03                   11.77
# 3                6.00                    1.65                    1.54
# 4                5.00                    0.23                    0.23
# 5                6.40                    1.46                    1.37
# 6                4.50                    0.60                    0.59
# 7                5.00                    1.60                    1.69
# 8               12.20                    8.01                    8.12
# 9                9.50                    5.25                    5.16
# 10               7.50                    5.91                    5.97
# 11               8.00                    5.15                    5.27
# 12               7.50                    5.47                    5.58
# 13               5.00                    3.53                    3.55
# 14               2.80                    1.38                    1.40
# 15               7.50                    6.18                    6.05
# 16               6.50                    2.00                    2.05
# 17               6.00                    1.70                    1.66
# 18               5.00                    0.85                    0.86
# 19               5.50                    0.38                    0.37
# 20               5.90                    0.72                    0.72
# 21               8.80                    1.23                    1.22
# 22               6.50                   -0.19                   -0.19
# 23               7.50                    0.84                    0.83
# 24               7.00                    0.48                    0.48
# 25               6.00                    0.29                    0.29
# 26               6.00                   -0.72                   -0.72
# 27               7.15                    0.42                    0.42
# 28               8.00                   -2.64                   -2.67
# 29               9.00                    1.12                    1.18
# 30               6.00                    0.84                    0.88
# 31               5.00                    0.47                    0.47
# 32              10.50                    1.55                    1.55
# 33               6.00                    0.49                    0.49
# 34               7.80                    1.13                    1.13
# 35               8.00                    0.02                    0.02
# 36               0.00                    0.32                    0.32
# 37               9.60                    1.87                    1.87
# 38               7.50                    0.82                    0.82
# 39               5.50                    0.70                    0.70
#
#         Remarks Water Level Rising or Falling  24 Hr RF in mm at 8.30 am  \
# 0        Normal                        Stable                        0.0
# 1        Normal                        Stable                       16.2
# 2        Normal                        Stable                       26.5
# 3        Normal                        Stable                       25.6
# 4        Normal                        Stable                        2.5
# 5        Normal                        Stable                      175.8
# 6        Normal                        Stable                        5.5
# 7        Normal                        Stable                       15.0
# 8        Normal                        Stable                      100.7
# 9        Normal                        Stable                      141.3
# 10        Alert                        Rising                       49.0
# 11        Alert                        Rising                       15.5
# 12        Alert                        Rising                       77.9
# 13        Alert                        Rising                       45.7
# 14        Alert                        Rising                       38.4
# 15  Minor Flood                       Falling                        7.5
# 16       Normal                        Stable                      132.3
# 17       Normal                        Stable                       42.7
# 18       Normal                        Stable                        9.5
# 19       Normal                        Stable                        0.0
# 20       Normal                        Stable                        0.0
# 21       Normal                        Stable                        0.0
# 22       Normal                        Stable                        0.0
# 23       Normal                        Stable                        0.0
# 24       Normal                        Stable                        0.0
# 25       Normal                        Stable                        0.0
# 26       Normal                        Stable                        0.0
# 27       Normal                        Stable                        0.0
# 28       Normal                        Stable                        0.0
# 29       Normal                        Stable                        0.0
# 30       Normal                        Stable                        0.0
# 31       Normal                        Stable                        0.0
# 32       Normal                        Stable                        0.0
# 33       Normal                        Stable                        0.0
# 34       Normal                        Stable                        0.0
# 35       Normal                        Stable                        0.0
# 36       Normal                        Stable                        0.0
# 37       Normal                        Stable                        1.3
# 38       Normal                        Stable                        0.3
# 39       Normal                        Stable                        0.1
#
#     Latitude  Longitude
# 0   6.927100  79.861200
# 1   6.897834  80.081429
# 2   6.966667  80.183333
# 3   6.997220  80.411110
# 4   7.196500  80.273900
# 5   6.934900  80.338000
# 6   6.838400  80.614700
# 7   6.611000  80.061600
# 8   6.744400  80.207000
# 9   6.705600  80.384700
# 10  6.494300  80.234400
# 11  6.642630  80.175480
# 12  6.334700  80.342200
# 13  6.168800  80.179400
# 14  7.503600  80.595200
# 15  6.109200  80.484100
# 16  6.207100  80.463200
# 17  6.250000  80.567000
# 18  6.340800  80.895900
# 19  6.434700  81.130800
# 20  6.737700  81.103100
# 21  6.534500  81.122400
# 22  6.413500  81.332600
# 23  6.890000  81.298400
# 24  6.906500  81.561000
# 25  7.392500  81.243600
# 26  7.913600  81.088900
# 27  7.905100  81.131300
# 28  7.329900  80.985700
# 29  7.269900  80.593800
# 30  7.054800  80.533500
# 31  7.092600  81.049500
# 32  8.618100  80.829400
# 33  8.726100  80.675000
# 34  8.572300  80.257200
# 35  7.986500  80.287900
# 36  8.032700  80.774100
# 37  7.288700  79.980800
# 38  7.331800  80.123300
# 39  7.877400  80.700300

# %% [markdown]
# Saving the dataframe in .xlsx format

# %%
#df.to_excel("C:/Users/User/Desktop/Project/Data2/"+ new_date +".xlsx")
